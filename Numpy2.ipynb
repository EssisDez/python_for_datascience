# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#check it

import numpy as np
import matplotlib.pyplot as plt
x = np.array([80,85,90,95,100,105,110,115,120,125])
y = np.array([240,250,260,270,280,290,300,310,320330,125])
plt.plot(x,y)
plt.xlablel("Average pulse")
plt.ylabel("calories")

plot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       6 y = np.array([240,250,260,270,280,290,300,310,320330,125])
#       7 plt.plot(x,y)
# ----> 8 plt.xlablel("Average pulse")
#       9 plt.ylabel("calories")
#      11 plot.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlablel'

# %%
import pandas as pd

data1 = {"Name":["Laulo","Doumi","Yass","Grachoo"],
        "Age": [23,24,25,26], 
         "Address": ["Faya","Bingerville","Yop","Bingerville"],
         "Qualification":["HR","Marketer","Finance","Advisory"]}

data2 = {"Name":["Sarah","Vero","Ericka","Mapol"],
        "Age": [23,24,25,26], 
         "Address": ["Yop","Noe","Cocody","Yop"],
         "Qualification":["HR","Marketer","Finance","Advisory"]}
df= pd.dataframe(data1, index [0,1,2,3])

df1= pd.dataframe(data1, index [4,5,6,7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 12
#       3 data1 = {"Name":["Laulo","Doumi","Yass","Grachoo"],
#       4         "Age": [23,24,25,26],
#       5          "Address": ["Faya","Bingerville","Yop","Bingerville"],
#       6          "Qualification":["HR","Marketer","Finance","Advisory"]}
#       8 data2 = {"Name":["Sarah","Vero","Ericka","Mapol"],
#       9         "Age": [23,24,25,26],
#      10          "Address": ["Yop","Noe","Cocody","Yop"],
#      11          "Qualification":["HR","Marketer","Finance","Advisory"]}
# ---> 12 df= pd.dataframe(data1, index [0,1,2,3])
#      14 df1= pd.dataframe(data1, index [4,5,6,7])
#
# AttributeError: module 'pandas' has no attribute 'dataframe'

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, color= "r")
plt.show()

# %%
import matplotlib.pyplot as pyplot

pyplot.bar([0.25,2.25,3.25,5.25,7.25],[300,400,200,600,700],
        label="Carpenter", color="b", width = 0.5)
pyplot.bar([0.75,2.75,3.75,5.75,7.75],[50,30,20,50,60],
           label="Plumber", color="B", width = 5)
pyplot.legend()
pyplot.xlabel("days")
pyplot.ylabel("wage")
pyplot.title("details")

pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2365, in Axes._parse_bar_color_args(self, kwargs)
#    2364 try:
# -> 2365     facecolor = mcolors.to_rgba_array(facecolor)
#    2366 except ValueError as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:498, in to_rgba_array(c, alpha)
#     497 if isinstance(c, str):
# --> 498     raise ValueError(f"{c!r} is not a valid color value.")
#     500 if len(c) == 0:
#
# ValueError: 'B' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 import matplotlib.pyplot as pyplot
#       2 pyplot.bar([0.25,2.25,3.25,5.25,7.25],[300,400,200,600,700],
#       3 label="Carpenter", color="b", width = 0.5)
# ----> 4 pyplot.bar([0.75,2.75,3.75,5.75,7.75],[50,30,20,50,60],
#       5            label="Plumber", color="B", width = 5)
#       6 pyplot.legend()
#       7 pyplot.xlabel("days")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2981, in bar(x, height, width, bottom, align, data, **kwargs)
#    2970 @_copy_docstring_and_deprecators(Axes.bar)
#    2971 def bar(
#    2972     x: float | ArrayLike,
#    (...)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#    2984         width=width,
#    2985         bottom=bottom,
#    2986         align=align,
#    2987         **({"data": data} if data is not None else {}),
#    2988         **kwargs,
#    2989     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2499, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2378 r"""
#    2379 Make a bar plot.
#    2380
#    (...)
#    2496 bar. See :doc:`/gallery/lines_bars_and_markers/bar_stacked`.
#    2497 """
#    2498 kwargs = cbook.normalize_kwargs(kwargs, mpatches.Patch)
# -> 2499 facecolor, edgecolor = self._parse_bar_color_args(kwargs)
#    2501 linewidth = kwargs.pop('linewidth', None)
#    2502 hatch = kwargs.pop('hatch', None)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:2367, in Axes._parse_bar_color_args(self, kwargs)
#    2365     facecolor = mcolors.to_rgba_array(facecolor)
#    2366 except ValueError as err:
# -> 2367     raise ValueError(
#    2368         "'facecolor' or 'color' argument must be a valid color or"
#    2369             "sequence of colors."
#    2370     ) from err
#    2372 return facecolor, edgecolor
#
# ValueError: 'facecolor' or 'color' argument must be a valid color orsequence of colors.
